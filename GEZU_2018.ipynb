# %%
import os
import pandas as pd

data_folder = "donnees"

os.listdir(data_folder)
# Out:
# ['layer_buildings.shx',
#  'layer_buildings.sbx',
#  'layer_buildings.sbn',
#  'consommations_specifiques.csv',
#  'layer_buildings.shp',
#  'layer_buildings.shp.xml',
#  'donnees_batiments.csv',
#  'layer_buildings.dbf',
#  'layer_buildings.prj',
#  'agent_ener_perf.csv']

# %%
raw_data = pd.read_csv(os.path.join(data_folder, 'donnees_batiments.csv'), index_col=0)
raw_data.head()
# Out:
#         TypeAffectation PeriodeConstruction AgentEnergetique  \
# ID
# 1   Immeuble de bureaux           1981-1985           Mazout
# 2   Batiment commercial           2011-2015           Mazout
# 3   Immeuble de bureaux           1971-1980      Electricite
# 4   Immeuble de bureaux           1981-1985      Gaz naturel
# 5      Maison mitoyenne           1981-1985      Gaz naturel
#
#     NbrNiveauxChauffes  EmpreinteSol_[m2]
# ID
# 1                    3                518
# 2                    1               1203
# 3                    3                428
# 4                    4                985
# 5                    4               1275

# %%
data = raw_data.copy()

ratio_sre = 0.9
data["SRE_[m2]"] = ratio_sre * data["EmpreinteSol_[m2]"] * data["NbrNiveauxChauffes"]
data.head()
# Out:
#         TypeAffectation PeriodeConstruction AgentEnergetique  \
# ID
# 1   Immeuble de bureaux           1981-1985           Mazout
# 2   Batiment commercial           2011-2015           Mazout
# 3   Immeuble de bureaux           1971-1980      Electricite
# 4   Immeuble de bureaux           1981-1985      Gaz naturel
# 5      Maison mitoyenne           1981-1985      Gaz naturel
#
#     NbrNiveauxChauffes  EmpreinteSol_[m2]  SRE_[m2]
# ID
# 1                    3                518    1398.6
# 2                    1               1203    1082.7
# 3                    3                428    1155.6
# 4                    4                985    3546.0
# 5                    4               1275    4590.0
